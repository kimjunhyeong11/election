# %%
# 라이브러리 불러오기
import pandas as pd
import folium
import json
import webbrowser

#안성시 선거 데이터를 불러와서 데이터프레임으로 변환
df = pd.read_excel(".\\제21대_개표상황(안성시).xlsx")
df.columns = df.columns.map(str)
df.columns

#안성시 읍면동 경계 정보를 가진 json 파일 불러오기
geo_path = open(".\\안성시_지도.json",'r',encoding = 'utf-8').read()
geo_path
geo_str = json.loads(geo_path)

#안성시 지도 그리기 초기좌표 안성시청으로 지정
map = folium.Map(location=[37.0112668,127.2536452],zoom_start=11)
folium.GeoJson(geo_str,name='json_data').add_to(map)

#지도를 HTML 파일로 저장하기
map.save('.\\안성시_지도.html')
webbrowser.open_new('.\\안성시_지도.html')
# Out:
# True

# %%
#라이브러리 불러오기
import pandas as pd
import folium
import json
import webbrowser

#안성시 선거 데이터를 불러와서 데이터프레임으로 변환
df = pd.read_excel(".\\제21대_개표상황(안성시).xlsx")
df.columns = df.columns.map(str)
df.columns

#안성시 읍면동 경계 정보를 가진 json 파일 불러오기
geo_path = open(".\\안성시_지도.json",'r',encoding = 'utf-8').read()
geo_path
geo_str = json.loads(geo_path)

#안성시 지도 그리기 초기좌표 안성시청으로 지정
map = folium.Map(location=[37.0112668,127.2536452],zoom_start=11)
folium.GeoJson(geo_str,name='json_data').add_to(map)

#지역별 우세정당 마커 표시하기
folium.Marker([37.0905555,127.477015], popup='일죽면', icon = folium.Icon(color='red')).add_to(map)
folium.Marker([37.078454, 127.422274], popup='죽산면', icon = folium.Icon(color='red')).add_to(map)
folium.Marker([37.0730016, 127.374058], popup='삼죽면', icon = folium.Icon(color='red')).add_to(map)
folium.Marker([37.0231516, 127.291262], popup='보개면', icon = folium.Icon(color='red')).add_to(map)
folium.Marker([36.9971979, 127.3152692], popup='금광면', icon = folium.Icon(color='blue')).add_to(map)
folium.Marker([37.0056481, 127.274264], popup='안성동', icon = folium.Icon(color='blue')).add_to(map)
folium.Marker([37.0010805, 127.172631], popup='공도읍', icon = folium.Icon(color='blue')).add_to(map)
folium.Marker([36.9430117, 127.259222], popup='서운면', icon = folium.Icon(color='red')).add_to(map)
folium.Marker([36.9783815, 127.217359], popup='미양면', icon = folium.Icon(color='red')).add_to(map)
folium.Marker([37.0125295, 127.23776], popup='대덕면', icon = folium.Icon(color='blue')).add_to(map)
folium.Marker([37.0598416, 127.194654], popup='양성면', icon = folium.Icon(color='red')).add_to(map)
folium.Marker([37.0826588, 127.2612999], popup='고삼면', icon = folium.Icon(color='red')).add_to(map)
folium.Marker([37.0397006, 127.129679], popup='원곡면', icon = folium.Icon(color='red')).add_to(map)

map.save('.\\지역우세정당.html')
webbrowser.open_new('.\\지역우세정당.html')
# Out:
# True

# %%
#라이브러리 불러오기
import pandas as pd
import folium
import json
import webbrowser

#안성시 선거 데이터를 불러와서 데이터프레임으로 변환
df = pd.read_excel(".\\제21대_개표상황(안성시).xlsx")
df.columns = df.columns.map(str)
df.columns

#안성시 읍면동 경계 정보를 가진 json 파일 불러오기
geo_path = open(".\\안성시_지도.json",'r',encoding = 'utf-8').read()
geo_path
geo_str = json.loads(geo_path)

#안성시 지도 그리기 초기좌표 안성시청으로 지정
map = folium.Map(location=[37.0112668,127.2536452],zoom_start=11)
folium.GeoJson(geo_str,name='json_data').add_to(map)

map.choropleth(geo_data = geo_str,
              data = df,
              columns = ['투표구명','투표수'],
              highlight = True,
              fill_color = 'PuRd', fill_opacity=0.7, line_opacity=0.3,
              key_on = 'feature.properties.EMD_KOR_NM',
              legend_name = '투표수')

# 투표수와 당선인 마커 표시하기
popup = folium.Popup('<b>일죽면</b><br>''투표수 : 6478',max_width=400)  # 글자 짤림 방지 위해 팝업 너비 설정
folium.Marker([37.0905555,127.477015], popup=popup, icon = folium.Icon(color='red')).add_to(map)
popup = folium.Popup('<b>죽산면</b><br>''투표수 : 6152',max_width=400)
folium.Marker([37.078454, 127.422274], popup=popup, icon = folium.Icon(color='red')).add_to(map)
popup = folium.Popup('<b>삼죽면</b><br>''투표수 : 3078',max_width=400)
folium.Marker([37.0730016, 127.374058], popup=popup, icon = folium.Icon(color='red')).add_to(map)
popup = folium.Popup('<b>보개면</b><br>''투표수 : 5166',max_width=400)
folium.Marker([37.0231516, 127.291262], popup=popup, icon = folium.Icon(color='red')).add_to(map)
popup = folium.Popup('<b>금광면</b><br>''투표수 : 6287',max_width=400)
folium.Marker([36.9971979, 127.3152692], popup=popup, icon = folium.Icon(color='blue')).add_to(map)
popup = folium.Popup('<b>안성동</b><br>''투표수 : 45376',max_width=400)
folium.Marker([37.0056481, 127.274264], popup=popup, icon = folium.Icon(color='blue')).add_to(map)
popup = folium.Popup('<b>공도읍</b><br>''투표수 : 41975',max_width=400)
folium.Marker([37.0010805, 127.172631], popup=popup, icon = folium.Icon(color='blue')).add_to(map)
popup = folium.Popup('<b>서운면</b><br>''투표수 : 3243',max_width=400)
folium.Marker([36.9430117, 127.259222], popup=popup, icon = folium.Icon(color='red')).add_to(map)
popup = folium.Popup('<b>미양면</b><br>''투표수 : 5062',max_width=400)
folium.Marker([36.9783815, 127.217359], popup=popup, icon = folium.Icon(color='red')).add_to(map)
popup = folium.Popup('<b>대덕면</b><br>''투표수 : 12556',max_width=400)
folium.Marker([37.0125295, 127.23776], popup=popup, icon = folium.Icon(color='blue')).add_to(map)
popup = folium.Popup('<b>양성면</b><br>''투표수 : 4776',max_width=400)
folium.Marker([37.0598416, 127.194654], popup=popup, icon = folium.Icon(color='red')).add_to(map)
popup = folium.Popup('<b>고삼면</b><br>''투표수 : 2157',max_width=400)
folium.Marker([37.0826588, 127.2612999], popup=popup, icon = folium.Icon(color='red')).add_to(map)
popup = folium.Popup('<b>원곡면</b><br>''투표수 : 5114',max_width=400)
folium.Marker([37.0397006, 127.129679], popup=popup, icon = folium.Icon(color='red')).add_to(map)

# 지도를 HTML 파일로 저장하기
map.save('.\\지역구_투표수.html')
webbrowser.open_new('.\\지역구_투표수.html')
# Out:
# True

# %%
#라이브러리 불러오기
import pandas as pd
import folium
import json
import webbrowser

#안성시 선거 데이터를 불러와서 데이터프레임으로 변환
df = pd.read_excel(".\\제21대_개표상황(안성시).xlsx")
df.columns = df.columns.map(str)
df.columns

#안성시 읍면동 경계 정보를 가진 json 파일 불러오기
geo_path = open(".\\안성시_지도.json",'r',encoding = 'utf-8').read()
geo_path
geo_str = json.loads(geo_path)

#안성시 지도 그리기 초기좌표 안성시청으로 지정
map = folium.Map(location=[37.0112668,127.2536452],zoom_start=11)
folium.GeoJson(geo_str,name='json_data').add_to(map)

map.choropleth(geo_data = geo_str,
              data = df,
              columns = ['투표구명','투표수'],
              highlight = True,
              fill_color = 'Blues', fill_opacity=0.7, line_opacity=0.3,
              key_on = 'feature.properties.EMD_KOR_NM',
              legend_name = '이규민 지역별 득표율')

# 이규민 득표율과 당선인 마커 표시하기
popup = folium.Popup('<b>일죽면</b><br>''득표율 : 40%',max_width=400)  # 글자 짤림 방지 위해 팝업 너비 설정
folium.Marker([37.0905555,127.477015], popup=popup, icon = folium.Icon(color='red')).add_to(map)
popup = folium.Popup('<b>죽산면</b><br>''득표율 : 44%',max_width=400)
folium.Marker([37.078454, 127.422274], popup=popup, icon = folium.Icon(color='red')).add_to(map)
popup = folium.Popup('<b>삼죽면</b><br>''득표율 : 46%',max_width=400)
folium.Marker([37.0730016, 127.374058], popup=popup, icon = folium.Icon(color='red')).add_to(map)
popup = folium.Popup('<b>보개면</b><br>''득표율 : 44%',max_width=400)
folium.Marker([37.0231516, 127.291262], popup=popup, icon = folium.Icon(color='red')).add_to(map)
popup = folium.Popup('<b>금광면</b><br>''득표율 : 50%',max_width=400)
folium.Marker([36.9971979, 127.3152692], popup=popup, icon = folium.Icon(color='blue')).add_to(map)
popup = folium.Popup('<b>안성동</b><br>''득표율 : 51%',max_width=400)
folium.Marker([37.0056481, 127.274264], popup=popup, icon = folium.Icon(color='blue')).add_to(map)
popup = folium.Popup('<b>공도읍</b><br>''득표율 : 57%',max_width=400)
folium.Marker([37.0010805, 127.172631], popup=popup, icon = folium.Icon(color='blue')).add_to(map)
popup = folium.Popup('<b>서운면</b><br>''득표율 : 40%',max_width=400)
folium.Marker([36.9430117, 127.259222], popup=popup, icon = folium.Icon(color='red')).add_to(map)
popup = folium.Popup('<b>미양면</b><br>''득표율 : 45%',max_width=400)
folium.Marker([36.9783815, 127.217359], popup=popup, icon = folium.Icon(color='red')).add_to(map)
popup = folium.Popup('<b>대덕면</b><br>''득표율 : 53%',max_width=400)
folium.Marker([37.0125295, 127.23776], popup=popup, icon = folium.Icon(color='blue')).add_to(map)
popup = folium.Popup('<b>양성면</b><br>''득표율 : 38%',max_width=400)
folium.Marker([37.0598416, 127.194654], popup=popup, icon = folium.Icon(color='red')).add_to(map)
popup = folium.Popup('<b>고삼면</b><br>''득표율 : 44%',max_width=400)
folium.Marker([37.0826588, 127.2612999], popup=popup, icon = folium.Icon(color='red')).add_to(map)
popup = folium.Popup('<b>원곡면</b><br>''득표율 : 43%',max_width=400)
folium.Marker([37.0397006, 127.129679], popup=popup, icon = folium.Icon(color='red')).add_to(map)

# 지도를 HTML 파일로 저장하기
map.save('.\\이규민_득표율.html')
webbrowser.open_new('.\\이규민_득표율.html')
# Out:
# True

# %%
# 라이브러리 불러오기
import pandas as pd
import folium
import json
import webbrowser

# 안성시 선거 데이터를 불러와서 데이터프레임으로 변환
df = pd.read_excel('.\\제21대_개표상황(안성시).xlsx')  
df.columns = df.columns.map(str)

# 안성시 읍면동 경계 정보를 가진 geo-json 파일 불러오기
geo_path = open('.\\안성시_지도.json', 'r', encoding='utf-8').read()
geo_str = json.loads(geo_path)

# 안성시 지도 그리기
map = folium.Map(location=[37.0112668,127.2536452],zoom_start=11)
folium.GeoJson(geo_str, name='json_data').add_to(map)

# Choropleth 클래스로 득표율 단계구분도 표시하기
map.choropleth(geo_data = geo_str,  # 지도 경계
               data = df,      # 표시하려는 데이터
               columns = ['투표구명','김학용_득표율'],  # 열 지정
               highlight = True,
               fill_color='Reds', fill_opacity=0.7, line_opacity=0.3,
               key_on='feature.properties.EMD_KOR_NM',
               legend_name = '김학용 지역별 득표율')

# 김학용 득표율과 당선인 마커 표시하기
popup = folium.Popup('<b>일죽면</b><br>''득표율 : 57%',max_width=400)  # 글자 짤림 방지 위해 팝업 너비 설정
folium.Marker([37.0905555,127.477015], popup=popup, icon = folium.Icon(color='red')).add_to(map)
popup = folium.Popup('<b>죽산면</b><br>''득표율 : 53%',max_width=400)
folium.Marker([37.078454, 127.422274], popup=popup, icon = folium.Icon(color='red')).add_to(map)
popup = folium.Popup('<b>삼죽면</b><br>''득표율 : 49%',max_width=400)
folium.Marker([37.0730016, 127.374058], popup=popup, icon = folium.Icon(color='red')).add_to(map)
popup = folium.Popup('<b>보개면</b><br>''득표율 : 52%',max_width=400)
folium.Marker([37.0231516, 127.291262], popup=popup, icon = folium.Icon(color='red')).add_to(map)
popup = folium.Popup('<b>금광면</b><br>''득표율 : 47%',max_width=400)
folium.Marker([36.9971979, 127.3152692], popup=popup, icon = folium.Icon(color='blue')).add_to(map)
popup = folium.Popup('<b>안성동</b><br>''득표율 : 46%',max_width=400)
folium.Marker([37.0056481, 127.274264], popup=popup, icon = folium.Icon(color='blue')).add_to(map)
popup = folium.Popup('<b>공도읍</b><br>''득표율 : 41%',max_width=400)
folium.Marker([37.0010805, 127.172631], popup=popup, icon = folium.Icon(color='blue')).add_to(map)
popup = folium.Popup('<b>서운면</b><br>''득표율 : 56%',max_width=400)
folium.Marker([36.9430117, 127.259222], popup=popup, icon = folium.Icon(color='red')).add_to(map)
popup = folium.Popup('<b>미양면</b><br>''득표율 : 52%',max_width=400)
folium.Marker([36.9783815, 127.217359], popup=popup, icon = folium.Icon(color='red')).add_to(map)
popup = folium.Popup('<b>대덕면</b><br>''득표율 : 44%',max_width=400)
folium.Marker([37.0125295, 127.23776], popup=popup, icon = folium.Icon(color='blue')).add_to(map)
popup = folium.Popup('<b>양성면</b><br>''득표율 : 58%',max_width=400)
folium.Marker([37.0598416, 127.194654], popup=popup, icon = folium.Icon(color='red')).add_to(map)
popup = folium.Popup('<b>고삼면</b><br>''득표율 : 53%',max_width=400)
folium.Marker([37.0826588, 127.2612999], popup=popup, icon = folium.Icon(color='red')).add_to(map)
popup = folium.Popup('<b>원곡면</b><br>''득표율 : 53%',max_width=400)
folium.Marker([37.0397006, 127.129679], popup=popup, icon = folium.Icon(color='red')).add_to(map)

# 지도를 HTML 파일로 저장하기
map.save('.\\김학용_득표율.html')
webbrowser.open_new('.\\김학용_득표율.html')
# Out:
# True

# %%
# 라이브러리 불러오기
import pandas as pd
import folium
import json
import webbrowser

# 안성시 선거 데이터를 불러와서 데이터프레임으로 변환
df = pd.read_excel('.\\제21대_개표상황(안성시).xlsx')  
df.columns = df.columns.map(str)

# 안성시 읍면동 경계 정보를 가진 geo-json 파일 불러오기
geo_path = open('.\\안성시_지도.json', 'r', encoding='utf-8').read()
geo_str = json.loads(geo_path)

# 안성시 지도 그리기
map = folium.Map(location=[37.0112668,127.2536452],zoom_start=11)
folium.GeoJson(geo_str, name='json_data').add_to(map)

# Choropleth 클래스로 득표율 단계구분도 표시하기
map.choropleth(geo_data = geo_str,  # 지도 경계
               data = df,      # 표시하려는 데이터
               columns = ['투표구명','송민정_득표율'],  # 열 지정
               highlight = True,
               fill_color='Oranges', fill_opacity=0.7, line_opacity=0.3,
               key_on='feature.properties.EMD_KOR_NM',
               legend_name = '송민정 지역별 득표율')

# 송민정 득표율과 당선인 마커 표시하기
popup = folium.Popup('<b>일죽면</b><br>''득표율 : 1%',max_width=400)  # 글자 짤림 방지 위해 팝업 너비 설정
folium.Marker([37.0905555,127.477015], popup=popup, icon = folium.Icon(color='red')).add_to(map)
popup = folium.Popup('<b>죽산면</b><br>''득표율 : 1%',max_width=400)
folium.Marker([37.078454, 127.422274], popup=popup, icon = folium.Icon(color='red')).add_to(map)
popup = folium.Popup('<b>삼죽면</b><br>''득표율 : 1%',max_width=400)
folium.Marker([37.0730016, 127.374058], popup=popup, icon = folium.Icon(color='red')).add_to(map)
popup = folium.Popup('<b>보개면</b><br>''득표율 : 2%',max_width=400)
folium.Marker([37.0231516, 127.291262], popup=popup, icon = folium.Icon(color='red')).add_to(map)
popup = folium.Popup('<b>금광면</b><br>''득표율 : 1%',max_width=400)
folium.Marker([36.9971979, 127.3152692], popup=popup, icon = folium.Icon(color='blue')).add_to(map)
popup = folium.Popup('<b>안성동</b><br>''득표율 : 1%',max_width=400)
folium.Marker([37.0056481, 127.274264], popup=popup, icon = folium.Icon(color='blue')).add_to(map)
popup = folium.Popup('<b>공도읍</b><br>''득표율 : 1%',max_width=400)
folium.Marker([37.0010805, 127.172631], popup=popup, icon = folium.Icon(color='blue')).add_to(map)
popup = folium.Popup('<b>서운면</b><br>''득표율 : 2%',max_width=400)
folium.Marker([36.9430117, 127.259222], popup=popup, icon = folium.Icon(color='red')).add_to(map)
popup = folium.Popup('<b>미양면</b><br>''득표율 : 1%',max_width=400)
folium.Marker([36.9783815, 127.217359], popup=popup, icon = folium.Icon(color='red')).add_to(map)
popup = folium.Popup('<b>대덕면</b><br>''득표율 : 1%',max_width=400)
folium.Marker([37.0125295, 127.23776], popup=popup, icon = folium.Icon(color='blue')).add_to(map)
popup = folium.Popup('<b>양성면</b><br>''득표율 : 2%',max_width=400)
folium.Marker([37.0598416, 127.194654], popup=popup, icon = folium.Icon(color='red')).add_to(map)
popup = folium.Popup('<b>고삼면</b><br>''득표율 : 2%',max_width=400)
folium.Marker([37.0826588, 127.2612999], popup=popup, icon = folium.Icon(color='red')).add_to(map)
popup = folium.Popup('<b>원곡면</b><br>''득표율 : 1%',max_width=400)
folium.Marker([37.0397006, 127.129679], popup=popup, icon = folium.Icon(color='red')).add_to(map)

# 지도를 HTML 파일로 저장하기
map.save('.\\송민정_득표율.html')
webbrowser.open_new('.\\송민정_득표율.html')
# Out:
# True

# %%
import pandas as pd
import folium
import json
import webbrowser
import base64

# 안성시 선거 데이터를 불러와서 데이터프레임으로 변환
df = pd.read_excel('.\\제21대_개표상황(안성시).xlsx')  
df.columns = df.columns.map(str)

# 안성시 읍면동 경계 정보를 가진 geo-json 파일 불러오기
geo_path = open('.\\안성시_지도.json', 'r', encoding='utf-8').read()
geo_str = json.loads(geo_path)

# 안성시 지도 그리기
map = folium.Map(location=[37.0112668,127.2536452],zoom_start=11)
folium.GeoJson(geo_str, name='json_data').add_to(map)

# Choropleth 클래스로 득표율차단계구분도 표시하기
map.choropleth(geo_data = geo_str,  # 지도 경계
               data = df,      # 표시하려는 데이터
               columns = ['투표구명','득표율차'],  # 열 지정
               highlight = True,
               fill_color='RdBu', fill_opacity=0.7, line_opacity=0.3,
               key_on='feature.properties.EMD_KOR_NM',
               legend_name = '득표율차')

# 당선인 마커 표시하기
pic1 = base64.b64encode(open(".\\img\\img\\일죽면.jpg",'rb').read()).decode()
image_tag= '<img src="data:image/jpeg;base64,{}">'.format(pic1)
iframe = folium.IFrame(image_tag, width=370, height=240)
popup1 = folium.Popup(iframe, max_width=1000)
pic2 = base64.b64encode(open('.\\img\\img\\죽산면.jpg','rb').read()).decode()
image_tag= '<img src="data:image/jpeg;base64,{}">'.format(pic2)
iframe = folium.IFrame(image_tag, width=370, height=240)
popup2 = folium.Popup(iframe, max_width=1000)
pic3 = base64.b64encode(open('.\\img\\img\\삼죽면.jpg','rb').read()).decode()
image_tag= '<img src="data:image/jpeg;base64,{}">'.format(pic3)
iframe = folium.IFrame(image_tag, width=370, height=240)
popup3 = folium.Popup(iframe, max_width=1000)
pic4 = base64.b64encode(open('.\\img\\img\\보개면.jpg','rb').read()).decode()
image_tag= '<img src="data:image/jpeg;base64,{}">'.format(pic4)
iframe = folium.IFrame(image_tag, width=370, height=240)
popup4 = folium.Popup(iframe, max_width=1000)
pic5 = base64.b64encode(open('.\\img\\img\\금광면.jpg','rb').read()).decode()
image_tag= '<img src="data:image/jpeg;base64,{}">'.format(pic5)
iframe = folium.IFrame(image_tag, width=370, height=240)
popup5 = folium.Popup(iframe, max_width=1000)
pic6 = base64.b64encode(open('.\\img\\img\\안성동.jpg','rb').read()).decode()
image_tag= '<img src="data:image/jpeg;base64,{}">'.format(pic6)
iframe = folium.IFrame(image_tag, width=370, height=240)
popup6 = folium.Popup(iframe, max_width=1000)
pic7 = base64.b64encode(open('.\\img\\img\\공도읍.jpg','rb').read()).decode()
image_tag= '<img src="data:image/jpeg;base64,{}">'.format(pic7)
iframe = folium.IFrame(image_tag, width=370, height=240)
popup7 = folium.Popup(iframe, max_width=1000)
pic8 = base64.b64encode(open('.\\img\\img\\서운면.jpg','rb').read()).decode()
image_tag= '<img src="data:image/jpeg;base64,{}">'.format(pic8)
iframe = folium.IFrame(image_tag, width=370, height=240)
popup8 = folium.Popup(iframe, max_width=1000)
pic9 = base64.b64encode(open('.\\img\\img\\미양면.jpg','rb').read()).decode()
image_tag= '<img src="data:image/jpeg;base64,{}">'.format(pic9)
iframe = folium.IFrame(image_tag, width=370, height=240)
popup9 = folium.Popup(iframe, max_width=1000)
pic10 = base64.b64encode(open('.\\img\\img\\대덕면.jpg','rb').read()).decode()
image_tag= '<img src="data:image/jpeg;base64,{}">'.format(pic10)
iframe = folium.IFrame(image_tag, width=370, height=240)
popup10 = folium.Popup(iframe, max_width=1000)
pic11 = base64.b64encode(open('.\\img\\img\\양성면.jpg','rb').read()).decode()
image_tag= '<img src="data:image/jpeg;base64,{}">'.format(pic11)
iframe = folium.IFrame(image_tag, width=370, height=240)
popup11 = folium.Popup(iframe, max_width=1000)
pic12 = base64.b64encode(open('.\\img\\img\\고삼면.jpg','rb').read()).decode()
image_tag= '<img src="data:image/jpeg;base64,{}">'.format(pic12)
iframe = folium.IFrame(image_tag,width=370, height=240)
popup12 = folium.Popup(iframe, max_width=1000)
pic13 = base64.b64encode(open('.\\img\\img\\원곡면.jpg','rb').read()).decode()
image_tag= '<img src="data:image/jpeg;base64,{}">'.format(pic13)
iframe = folium.IFrame(image_tag, width=370, height=240)
popup13 = folium.Popup(iframe, max_width=1000)



# 당선인 마커 표시하기
folium.Marker([37.0905555,127.477015], popup=popup1, icon = folium.Icon(color='red')).add_to(map)
folium.Marker([37.078454, 127.422274], popup=popup2, icon = folium.Icon(color='red')).add_to(map)
folium.Marker([37.0730016, 127.374058], popup=popup3, icon = folium.Icon(color='red')).add_to(map)
folium.Marker([37.0231516, 127.291262], popup=popup4, icon = folium.Icon(color='red')).add_to(map)
folium.Marker([36.9971979, 127.3152692], popup=popup5, icon = folium.Icon(color='blue')).add_to(map)
folium.Marker([37.0056481, 127.274264], popup=popup6, icon = folium.Icon(color='blue')).add_to(map)
folium.Marker([37.0010805, 127.172631], popup=popup7, icon = folium.Icon(color='blue')).add_to(map)
folium.Marker([36.9430117, 127.259222], popup=popup8, icon = folium.Icon(color='red')).add_to(map)
folium.Marker([36.9783815, 127.217359], popup=popup9, icon = folium.Icon(color='red')).add_to(map)
folium.Marker([37.0125295, 127.23776], popup=popup10, icon = folium.Icon(color='blue')).add_to(map)
folium.Marker([37.0598416, 127.194654], popup=popup11, icon = folium.Icon(color='red')).add_to(map)
folium.Marker([37.0826588, 127.2612999], popup=popup12, icon = folium.Icon(color='red')).add_to(map)
folium.Marker([37.0397006, 127.129679], popup=popup13, icon = folium.Icon(color='red')).add_to(map)


# 지도를 HTML 파일로 저장하기
map.save('.\\득표율차_막대.html')
webbrowser.open_new('.\\득표율차_막대.html')
# Out:
# True

# %%
import pandas as pd
import folium
import json
import webbrowser
import base64

# 안성시 선거 데이터를 불러와서 데이터프레임으로 변환
df = pd.read_excel('.\\제21대_개표상황(안성시).xlsx')  
df.columns = df.columns.map(str)

# 안성시 읍면동 경계 정보를 가진 geo-json 파일 불러오기
geo_path = open('.\\안성시_지도.json', 'r', encoding='utf-8').read()
geo_str = json.loads(geo_path)

# 안성시 지도 그리기
map = folium.Map(location=[37.0112668,127.2536452],zoom_start=11)
folium.GeoJson(geo_str, name='json_data').add_to(map)

# Choropleth 클래스로 득표율차단계구분도 표시하기
map.choropleth(geo_data = geo_str,  # 지도 경계
               data = df,      # 표시하려는 데이터
               columns = ['투표구명','득표율차'],  # 열 지정
               highlight = True,
               fill_color='RdBu', fill_opacity=0.7, line_opacity=0.3,
               key_on='feature.properties.EMD_KOR_NM',
               legend_name = '득표율차')

# 당선인 마커 표시하기
pic1 = base64.b64encode(open(".\\img\\파이차트\\일죽면.jpg",'rb').read()).decode()
image_tag= '<img src="data:image/jpeg;base64,{}">'.format(pic1)
iframe = folium.IFrame(image_tag, width=300, height=200)
popup1 = folium.Popup(iframe, max_width=1000)
pic2 = base64.b64encode(open('.\\img\\파이차트\\죽산면.jpg','rb').read()).decode()
image_tag= '<img src="data:image/jpeg;base64,{}">'.format(pic2)
iframe = folium.IFrame(image_tag, width=300, height=200)
popup2 = folium.Popup(iframe, max_width=1000)
pic3 = base64.b64encode(open('.\\img\\파이차트\\삼죽면.jpg','rb').read()).decode()
image_tag= '<img src="data:image/jpeg;base64,{}">'.format(pic3)
iframe = folium.IFrame(image_tag, width=300, height=200)
popup3 = folium.Popup(iframe, max_width=1000)
pic4 = base64.b64encode(open('.\\img\\파이차트\\보개면.jpg','rb').read()).decode()
image_tag= '<img src="data:image/jpeg;base64,{}">'.format(pic4)
iframe = folium.IFrame(image_tag, width=300, height=200)
popup4 = folium.Popup(iframe, max_width=1000)
pic5 = base64.b64encode(open('.\\img\\파이차트\\금광면.jpg','rb').read()).decode()
image_tag= '<img src="data:image/jpeg;base64,{}">'.format(pic5)
iframe = folium.IFrame(image_tag, width=300, height=200)
popup5 = folium.Popup(iframe, max_width=1000)
pic6 = base64.b64encode(open('.\\img\\파이차트\\안성동.jpg','rb').read()).decode()
image_tag= '<img src="data:image/jpeg;base64,{}">'.format(pic6)
iframe = folium.IFrame(image_tag, width=300, height=200)
popup6 = folium.Popup(iframe, max_width=1000)
pic7 = base64.b64encode(open('.\\img\\파이차트\\공도읍.jpg','rb').read()).decode()
image_tag= '<img src="data:image/jpeg;base64,{}">'.format(pic7)
iframe = folium.IFrame(image_tag, width=300, height=200)
popup7 = folium.Popup(iframe, max_width=1000)
pic8 = base64.b64encode(open('.\\img\\파이차트\\서운면.jpg','rb').read()).decode()
image_tag= '<img src="data:image/jpeg;base64,{}">'.format(pic8)
iframe = folium.IFrame(image_tag, width=300, height=200)
popup8 = folium.Popup(iframe, max_width=1000)
pic9 = base64.b64encode(open('.\\img\\파이차트\\미양면.jpg','rb').read()).decode()
image_tag= '<img src="data:image/jpeg;base64,{}">'.format(pic9)
iframe = folium.IFrame(image_tag, width=300, height=200)
popup9 = folium.Popup(iframe, max_width=1000)
pic10 = base64.b64encode(open('.\\img\\파이차트\\대덕면.jpg','rb').read()).decode()
image_tag= '<img src="data:image/jpeg;base64,{}">'.format(pic10)
iframe = folium.IFrame(image_tag, width=300, height=200)
popup10 = folium.Popup(iframe, max_width=1000)
pic11 = base64.b64encode(open('.\\img\\파이차트\\양성면.jpg','rb').read()).decode()
image_tag= '<img src="data:image/jpeg;base64,{}">'.format(pic11)
iframe = folium.IFrame(image_tag, width=300, height=200)
popup11 = folium.Popup(iframe, max_width=1000)
pic12 = base64.b64encode(open('.\\img\\파이차트\\고삼면.jpg','rb').read()).decode()
image_tag= '<img src="data:image/jpeg;base64,{}">'.format(pic12)
iframe = folium.IFrame(image_tag,width=300, height=200)
popup12 = folium.Popup(iframe, max_width=1000)
pic13 = base64.b64encode(open('.\\img\\파이차트\\원곡면.jpg','rb').read()).decode()
image_tag= '<img src="data:image/jpeg;base64,{}">'.format(pic13)
iframe = folium.IFrame(image_tag, width=300, height=200)
popup13 = folium.Popup(iframe, max_width=1000)



# 당선인 마커 표시하기
folium.Marker([37.0905555,127.477015], popup=popup1, icon = folium.Icon(color='red')).add_to(map)
folium.Marker([37.078454, 127.422274], popup=popup2, icon = folium.Icon(color='red')).add_to(map)
folium.Marker([37.0730016, 127.374058], popup=popup3, icon = folium.Icon(color='red')).add_to(map)
folium.Marker([37.0231516, 127.291262], popup=popup4, icon = folium.Icon(color='red')).add_to(map)
folium.Marker([36.9971979, 127.3152692], popup=popup5, icon = folium.Icon(color='blue')).add_to(map)
folium.Marker([37.0056481, 127.274264], popup=popup6, icon = folium.Icon(color='blue')).add_to(map)
folium.Marker([37.0010805, 127.172631], popup=popup7, icon = folium.Icon(color='blue')).add_to(map)
folium.Marker([36.9430117, 127.259222], popup=popup8, icon = folium.Icon(color='red')).add_to(map)
folium.Marker([36.9783815, 127.217359], popup=popup9, icon = folium.Icon(color='red')).add_to(map)
folium.Marker([37.0125295, 127.23776], popup=popup10, icon = folium.Icon(color='blue')).add_to(map)
folium.Marker([37.0598416, 127.194654], popup=popup11, icon = folium.Icon(color='red')).add_to(map)
folium.Marker([37.0826588, 127.2612999], popup=popup12, icon = folium.Icon(color='red')).add_to(map)
folium.Marker([37.0397006, 127.129679], popup=popup13, icon = folium.Icon(color='red')).add_to(map)


# 지도를 HTML 파일로 저장하기
map.save('.\\득표율차_파이.html')
webbrowser.open_new('.\\득표율차_파이.html')
# Out:
# True
